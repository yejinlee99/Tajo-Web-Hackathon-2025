# %%
import requests

# 본인의 네이버 클라우드 콘솔에서 발급받은 키를 여기에 입력
CLIENT_ID = "wkm3jx3t4o"
CLIENT_SECRET = "oWbxLTF19JAraHtfId5cV12iMma3JAMp7niOkhVa"

url = "https://maps.apigw.ntruss.com/map-direction-15/v1/driving"

params = {
    "start": "127.259624, 36.264081",  # 출발지: 경도, 위도
    "goal": "127.299242, 36.279915",   # 도착지: 경도, 위도
    "option": "traoptimal"              # 경로 최적화 옵션
}

headers = {
    "x-ncp-apigw-api-key-id": CLIENT_ID,
    "x-ncp-apigw-api-key": CLIENT_SECRET
}

response = requests.get(url, headers=headers, params=params)

print("상태코드:", response.status_code)
print("요청 URL:", response.url)
print("응답 내용:", response.text)
# Out:
# 상태코드: 200
# 요청 URL: https://maps.apigw.ntruss.com/map-direction-15/v1/driving?start=127.259624%2C+36.264081&goal=127.299242%2C+36.279915&option=traoptimal
# ...
